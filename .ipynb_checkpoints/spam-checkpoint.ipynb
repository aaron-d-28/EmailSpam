# %%
# %config IPCompleter.use_jedi = True  # or False if Jedi is buggy with your libs
# %config Completer.use_jedi = True
# %config IPCompleter.greedy = True  # For nested completion like obj.attr1.attr2

# %%
import numpy as np 
import pandas as pd

# %%
email = pd.read_csv('../emailspam/email.csv')

# %%
email.shape
# Out:
# (5573, 2)

# %%
email.sample(5)
# Out:
#      Category                                            Message
# 2327      ham  The Xmas story is peace.. The Xmas msg is love...
# 1112      ham  Awesome, think we can get an 8th at usf some t...
# 3568     spam  Collect your VALENTINE'S weekend to PARIS inc ...
# 3148      ham  Oh thats late! Well have a good night and i wi...
# 357      spam  Congratulations ur awarded 500 of CD vouchers ...

# %%
email.info
# Out:
# <bound method DataFrame.info of             Category                                            Message
# 0                ham  Go until jurong point, crazy.. Available only ...
# 1                ham                      Ok lar... Joking wif u oni...
# 2               spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3                ham  U dun say so early hor... U c already then say...
# 4                ham  Nah I don't think he goes to usf, he lives aro...
# ...              ...                                                ...
# 5568             ham               Will ü b going to esplanade fr home?
# 5569             ham  Pity, * was in mood for that. So...any other s...
# 5570             ham  The guy did some bitching but I acted like i'd...
# 5571             ham                         Rofl. Its true to its name
# 5572  {"mode":"full"                                    isActive:false}
#
# [5573 rows x 2 columns]>

# %%
email.rename(columns={'Category':'Issspam'},inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
email.Issspam = encoder.fit_transform(email['Issspam'])

# %%
email.sample(10)
# Out:
#       Issspam                                            Message
# 114         1  GENT! We are trying to contact you. Last weeke...
# 108         0  How would my ip address test that considering ...
# 2206        0  Haha, my legs and neck are killing me and my a...
# 1722        0  Am watching house – very entertaining – am get...
# 1456        1  Summers finally here! Fancy a chat or flirt wi...
# 2386        1  Someone has contacted our dating service and e...
# 556         0  O. Well uv causes mutations. Sunscreen is like...
# 1975        0  Thats cool. Where should i cum? On you or in y...
# 4858        0  Thanks  and ! Or bomb and date as my phone wan...
# 2491        0  Dun b sad.. It's over.. Dun thk abt it already...

# %%
email.duplicated().sum()
# Out:
# np.int64(415)

# %%
email = email.drop_duplicates(keep='first')
email.duplicated().sum()
# Out:
# np.int64(0)

# %%
email.Issspam.value_counts()
# Out:
# Issspam
# 0    4516
# 1     641
# 2       1
# Name: count, dtype: int64

# %%
email.drop(email[email.Issspam==2].index,inplace=True)
email.Issspam.value_counts()
# Out:
# /tmp/ipykernel_8312/3598660158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email.drop(email[email.Issspam==2].index,inplace=True)
# Issspam
# 0    4516
# 1     641
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


counts = email['Issspam'].value_counts()
labels = counts.index 

# Plot pie chart
plt.pie(counts, labels=labels, autopct="%0.3f%%")
plt.title("Distribution of Ham vs Spam")
plt.show()

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
import nltk
from typing import List
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/aaron/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
email['letterlen'] = email.Message.apply(len)
# Out:
# /tmp/ipykernel_8312/693664644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email['letterlen'] = email.Message.apply(len)

# %%
email['numwords'] = email.Message.apply(lambda x:len(tokenizer.tokenize(x)))
# Out:
# /tmp/ipykernel_8312/3166859425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email['numwords'] = email.Message.apply(lambda x:len(tokenizer.tokenize(x)))

# %%
email['Senlen'] = email.Message.apply(lambda x:len(nltk.sent_tokenize(x)))
# Out:
# /tmp/ipykernel_8312/1934115864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email['Senlen'] = email.Message.apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
email.head()
# Out:
#    Issspam                                            Message  letterlen  \
# 0        0  Go until jurong point, crazy.. Available only ...        111
# 1        0                      Ok lar... Joking wif u oni...         29
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...        155
# 3        0  U dun say so early hor... U c already then say...         49
# 4        0  Nah I don't think he goes to usf, he lives aro...         61
#
#    numwords  Senlen
# 0        20       2
# 1         6       2
# 2        33       2
# 3        11       1
# 4        14       1

# %%
import seaborn as sns 

sns.histplot(email[email.Issspam==0]['letterlen'])
sns.histplot(email[email.Issspam==1]['letterlen'])
# Out:
# <Axes: xlabel='letterlen', ylabel='Count'>

# %%
sns.histplot(email[email.Issspam==0]['numwords'])
sns.histplot(email[email.Issspam==1]['numwords'])
# Out:
# <Axes: xlabel='numwords', ylabel='Count'>

# %%
sns.pairplot(email,hue='Issspam')

# %%
corrs = email.drop(columns='Message').corr()
sns.heatmap(corrs)
# Out:
# <Axes: >

# %%
from nltk.corpus import stopwords
from copy import deepcopy
import string
stoppingwords = stopwords.words('english')
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()


def transformtext(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    strings=[]
    for i in text:
        if i.isalnum():
            strings.append(i)

    text=strings[:]
    strings.clear()

    for i in text:
        if i not in stoppingwords and i not in string.punctuation: 
            strings.append(i) 

    text=strings[:]
    strings.clear()

    for i in text:
        strings.append(ps.stem(i))
    
    return ' '.join(strings)

# %%
txt ="Wasgood my babies how u love loving loves!! "

# %%
transformtext(txt)
# Out:
# 'wasgood babi u love love love'

# %%
email['transformed_text'] = email.Message.apply(transformtext)
# Out:
# /tmp/ipykernel_8312/2552908711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email['transformed_text'] = email.Message.apply(transformtext)

# %%
email.transformed_text
# Out:
# 0       go jurong point crazi avail bugi n great world...
# 1                                   ok lar joke wif u oni
# 2       free entri 2 wkli comp win fa cup final tkt 21...
# 3                     u dun say earli hor u c alreadi say
# 4                    nah think goe usf live around though
#                               ...
# 5567    2nd time tri 2 contact u pound prize 2 claim e...
# 5568                              ü b go esplanad fr home
# 5569                                    piti mood suggest
# 5570    guy bitch act like interest buy someth els nex...
# 5571                                       rofl true name
# Name: transformed_text, Length: 5157, dtype: object

# %%
from wordcloud import WordCloud
wc = WordCloud.generate(width=50 ,height = 50 ,min_font_size = 10 , background_color ='white')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 from wordcloud import WordCloud
# ----> 2 wc = WordCloud.generate(width=50 ,height = 50 ,min_font_size = 10 , background_color ='white')
#
# TypeError: WordCloud.generate() got an unexpected keyword argument 'width'
